# %%
# Import libraries

import pandas as pd
import seaborn as sns
import numpy as np

import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure
from matplotlib.transforms import Bbox

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (11,7)

# Read in the data

df = pd.read_excel(r'C:\Users\shgre\Downloads\LEGO Table 2.xlsx')

# %%
df.head()
# Out:
#    year ParentTheme      SubTheme  SetsReleased
# 0  1950     Classic     Basic Set             1
# 1  1950     Classic  Supplemental             6
# 2  1953     Classic  Supplemental             4
# 3  1954     Classic  Supplemental            12
# 4  1954     Classic     Town Plan             2

# %%
df
# Out:
#       year   ParentTheme      SubTheme  SetsReleased
# 0     1950       Classic     Basic Set             1
# 1     1950       Classic  Supplemental             6
# 2     1953       Classic  Supplemental             4
# 3     1954       Classic  Supplemental            12
# 4     1954       Classic     Town Plan             2
# ...    ...           ...           ...           ...
# 1904  2017  Super Heroes        Marvel             7
# 1905  2017  Super Heroes    Spider-Man             1
# 1906  2017  Super Heroes      Superman             1
# 1907  2017          Town          City             6
# 1908  2017          Town          Fire             1
#
# [1909 rows x 4 columns]

# %%
# Scatter plot with sets released each year

plt.scatter(x=df['year'], y=df['SetsReleased'])

plt.title('Sets Released Each Year')

plt.xlabel('Year')

plt.ylabel('Sets Released')

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Let's use seaborn to get a better look

sns.scatterplot(x='year', y='SetsReleased', data=df, hue='ParentTheme')

plt.title('Sets Released Each Year')

plt.xlabel('Year')

plt.ylabel('Sets Released')

plt.legend(title='Parent Theme', bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
